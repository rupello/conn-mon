# %%
# http://graphviz.readthedocs.io/en/stable/manual.html

# %%
import graphviz

# %%
from graphviz import Digraph

# %%
dot = Digraph(comment='The Round Table')

# %%
dot.node('A', 'King Arthur')
dot.node('B', 'Sir Bedevere the Wise')
dot.node('L', 'Sir Lancelot the Brave')

dot.edges(['AB', 'AL'])
dot.edge('B', 'L', constraint='false')

# %%
dot.view()
# Out:
# 'Digraph.gv.pdf'

# %%
dot

# %%
# !ls
# Out:
# Digraph.gv	graphviz.ipynb	   test.png
# Digraph.gv.pdf	tcp-syn-ack.ipynb  test.png.pdf

# %%
# https://github.com/chebee7i/nxpd
    
import networkx as nx
from nxpd import draw
G = nx.cycle_graph(4, create_using=nx.DiGraph())
draw(G)
# Out:
# '/tmp/nx_88xMpL.png'

# %%
draw(G, show='ipynb')

# %%
G = nx.DiGraph()
G.graph['rankdir'] = 'LR'
G.graph['dpi'] = 120
G.add_cycle(range(4))
G.add_node(0, color='red', style='filled', fillcolor='pink')
G.add_node(1, shape='square')
G.add_node(3, style='filled', fillcolor='#00ffff')
G.add_edge(0, 1, color='red', style='dashed')
G.add_edge(3, 3, label='a')
draw(G, show='ipynb')
